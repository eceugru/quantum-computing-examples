# %% [markdown]
# Bir sırasız dizi içersinden bir eleman ararken bunun kuantumla daha iyi olacağını gösteren bir algoritmadır.

# %%
from qiskit import *
from qiskit.visualization import plot_histogram
# %matplotlib inline

# %%
#Classical Search
myList=[5,0,3,2,8,1,9]

# %%
def oracal(number):
    winningNumber=8
    if number == winningNumber:
        response=True
    else:
        response= False
    return response

# %%
for index, number in enumerate(myList):
    if oracal(number) is True:
        print(f"winning number index: {index}")
        print(f"execution count: {index +1}")
        break
# Out:
# winning number index: 4
# execution count: 5

# %%
# Quantum Model Grover's Algorithm

oracleCircuit=QuantumCircuit(2, name="oracalCircuit")
oracleCircuit.cz(0,1)
oracleCircuit.to_gate()
oracleCircuit.draw(output='mpl')

# %%
mainCircuit=QuantumCircuit(2,2)
mainCircuit.h([0,1])
mainCircuit.append(oracleCircuit,[0,1])
mainCircuit.draw(output='mpl')

# %%
reflectionCircuit = QuantumCircuit(2,name="reflectionCircuit")
reflectionCircuit.h([0,1])
reflectionCircuit.z([0,1])
reflectionCircuit.cz(0,1)
reflectionCircuit.h([0,1])
reflectionCircuit.to_gate()
reflectionCircuit.draw(output='mpl')

# %%
mainCircuit.append(reflectionCircuit,[0,1])
mainCircuit.measure([0,1],[0,1])
mainCircuit.draw(output='mpl')

# %% [markdown]
# Kuantum Bilgisayarlarda çalışma aşaması

# %% [markdown]
# Sonuç olarak tek adımda %100 ihtimal ile 11'i bulamaktadır.
